# %%
# 참고(딥러닝)

# %%
data = [[2,81], [4,93],[6,91],[8,97]]

# %%
x = [i[0] for i in data]
y = [i[1] for i in data]

# %%
data[0]
# Out:
# [2, 81]

# %%
data[1]
# Out:
# [4, 93]

# %%
data[0][0]
# Out:
# 2

# %%
data[0][1]
# Out:
# 81

# %%
# data[0][2]

# %% [markdown]
# NLP_CEO 연설 분석

# %%
import pandas as pd 
import numpy as np

# %%
pd.read_csv('./data/CEO3.csv', encoding='latin')
# Out:
#      number               firm  publishing country  \
# 0         2       Amorepacific           1   Korea
# 1         4       Amorepacific           3   Korea
# 2       502       Amorepacific           4   Korea
# 3         5    Asiana Airlines           1   Korea
# 4         6    Asiana Airlines           2   Korea
# ..      ...                ...         ...     ...
# 373     486  Wyndham Worldwide           1     USA
# 374     487  Wyndham Worldwide           2     USA
# 375     488  Wyndham Worldwide           3     USA
# 376     490             Xilinx           3     USA
# 377     623             Xilinx           4     USA
#
#                                                   text  Unnamed: 5  \
# 0    We will use beauty to change the world and bec...         NaN
# 1    AMOREPACIFC Group will endeavor to become a gr...         NaN
# 2    AMOREPACIFIC Group has been pursuing the path ...         NaN
# 3    This year marks the 25th anniversary of the es...         NaN
# 4    Since the inception, Asiana Airlines has pledg...         NaN
# ..                                                 ...         ...
# 373  Acting with integrity and providing a great  e...         NaN
# 374  With\ta\tunique\tglobal\tportfolio\tthat\tincl...         NaN
# 375  With\tthe\twidest\trange\tof\tplaces\tto\tstay...         NaN
# 376  These are exciting times for Xilinx, and the e...         NaN
# 377  These are exciting times at Xilinx. Systems an...         NaN
#
#      Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 450  \
# 0           NaN         NaN         NaN         NaN  ...           NaN
# 1           NaN         NaN         NaN         NaN  ...           NaN
# 2           NaN         NaN         NaN         NaN  ...           NaN
# 3           NaN         NaN         NaN         NaN  ...           NaN
# 4           NaN         NaN         NaN         NaN  ...           NaN
# ..          ...         ...         ...         ...  ...           ...
# 373         NaN         NaN         NaN         NaN  ...           NaN
# 374         NaN         NaN         NaN         NaN  ...           NaN
# 375         NaN         NaN         NaN         NaN  ...           NaN
# 376         NaN         NaN         NaN         NaN  ...           NaN
# 377         NaN         NaN         NaN         NaN  ...           NaN
#
#      Unnamed: 451  Unnamed: 452  Unnamed: 453  Unnamed: 454  Unnamed: 455  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1             NaN           NaN           NaN           NaN           NaN
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 373           NaN           NaN           NaN           NaN           NaN
# 374           NaN           NaN           NaN           NaN           NaN
# 375           NaN           NaN           NaN           NaN           NaN
# 376           NaN           NaN           NaN           NaN           NaN
# 377           NaN           NaN           NaN           NaN           NaN
#
#      Unnamed: 456  Unnamed: 457  Unnamed: 458  Unnamed: 459
# 0             NaN           NaN           NaN           NaN
# 1             NaN           NaN           NaN           NaN
# 2             NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...
# 373           NaN           NaN           NaN           NaN
# 374           NaN           NaN           NaN           NaN
# 375           NaN           NaN           NaN           NaN
# 376           NaN           NaN           NaN           NaN
# 377           NaN           NaN           NaN           NaN
#
# [378 rows x 460 columns]

# %%
df = pd.read_csv('./data/CEO3.csv', encoding='latin')
df[0:10]
# Out:
#    number                      firm  publishing country  \
# 0       2              Amorepacific           1   Korea
# 1       4              Amorepacific           3   Korea
# 2     502              Amorepacific           4   Korea
# 3       5           Asiana Airlines           1   Korea
# 4       6           Asiana Airlines           2   Korea
# 5       7           Asiana Airlines           3   Korea
# 6     503           Asiana Airlines           4   Korea
# 7      11  BNK Financial Group Inc.           3   Korea
# 8     504  BNK Financial Group Inc.           4   Korea
# 9      12                       BPA           3   Korea
#
#                                                 text  Unnamed: 5  Unnamed: 6  \
# 0  We will use beauty to change the world and bec...         NaN         NaN
# 1  AMOREPACIFC Group will endeavor to become a gr...         NaN         NaN
# 2  AMOREPACIFIC Group has been pursuing the path ...         NaN         NaN
# 3  This year marks the 25th anniversary of the es...         NaN         NaN
# 4  Since the inception, Asiana Airlines has pledg...         NaN         NaN
# 5  All of us will do our best without stopping fo...         NaN         NaN
# 6  First of all, I would like to express my heart...         NaN         NaN
# 7  Since the establishment of Busan Bank in 1967 ...         NaN         NaN
# 8  In March 2011, BNK Financial Group was launche...         NaN         NaN
# 9  I am pleased to introduce various sustainable ...         NaN         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 450  Unnamed: 451  \
# 0         NaN         NaN         NaN  ...           NaN           NaN
# 1         NaN         NaN         NaN  ...           NaN           NaN
# 2         NaN         NaN         NaN  ...           NaN           NaN
# 3         NaN         NaN         NaN  ...           NaN           NaN
# 4         NaN         NaN         NaN  ...           NaN           NaN
# 5         NaN         NaN         NaN  ...           NaN           NaN
# 6         NaN         NaN         NaN  ...           NaN           NaN
# 7         NaN         NaN         NaN  ...           NaN           NaN
# 8         NaN         NaN         NaN  ...           NaN           NaN
# 9         NaN         NaN         NaN  ...           NaN           NaN
#
#    Unnamed: 452  Unnamed: 453  Unnamed: 454  Unnamed: 455  Unnamed: 456  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN           NaN
# 8           NaN           NaN           NaN           NaN           NaN
# 9           NaN           NaN           NaN           NaN           NaN
#
#    Unnamed: 457  Unnamed: 458  Unnamed: 459
# 0           NaN           NaN           NaN
# 1           NaN           NaN           NaN
# 2           NaN           NaN           NaN
# 3           NaN           NaN           NaN
# 4           NaN           NaN           NaN
# 5           NaN           NaN           NaN
# 6           NaN           NaN           NaN
# 7           NaN           NaN           NaN
# 8           NaN           NaN           NaN
# 9           NaN           NaN           NaN
#
# [10 rows x 460 columns]

# %%
df.text
# Out:
# 0      We will use beauty to change the world and bec...
# 1      AMOREPACIFC Group will endeavor to become a gr...
# 2      AMOREPACIFIC Group has been pursuing the path ...
# 3      This year marks the 25th anniversary of the es...
# 4      Since the inception, Asiana Airlines has pledg...
#                              ...
# 373    Acting with integrity and providing a great  e...
# 374    With\ta\tunique\tglobal\tportfolio\tthat\tincl...
# 375    With\tthe\twidest\trange\tof\tplaces\tto\tstay...
# 376    These are exciting times for Xilinx, and the e...
# 377    These are exciting times at Xilinx. Systems an...
# Name: text, Length: 378, dtype: object

# %%
texts = df.text

# %%
from nltk.tokenize import RegexpTokenizer # 정규표현식 사용 정제
tokenizer = RegexpTokenizer(r'\w+')

# %%
from nltk.stem import WordNetLemmatizer # 표제어
lemmatizer = WordNetLemmatizer()

# %%
import nltk 
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\student\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = nltk.corpus.stopwords.words('english')

# %%
stop_words.extend([])

# %%
stop_words[0:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
from nltk import wordnet 
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\student\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
preprocessed_texts = [ ]

for text in texts.values: 
    tokenized_text = tokenizer.tokenize(text.lower()) # 소문자로 변경 
    lemmatized_text = [lemmatizer.lemmatize(token) for token in tokenized_text] 
    # 토큰화된 테스를 표제어 구성된 리스트 생성 
    stopped_text = [token for token in lemmatized_text if token not in stop_words]
    # 불용어가 아닌 토큰이라면, 표제어 리스트에서 토큰을 추출해 리스트로 만들기 
    preprocessed_texts.append(stopped_text)

# %%
preprocessed_texts[0:10]
# Out:
# [['use',
#   'beauty',
#   'change',
#   'world',
#   'become',
#   'company',
#   'customer',
#   'love',
#   'stakeholder',
#   'past',
#   '67',
#   'year',
#   'amorepacific',
#   'ha',
#   'embarked',
#   'long',
#   'journey',
#   'beauty',
#   'provide',
#   'happiness',
#   'pleasure',
#   'people',
#   'around',
#   'world',
#   'amorepacific',
#   'creation',
#   'beauty',
#   'product',
#   'stood',
#   'test',
#   'numerous',
#   'crisis',
#   'resulting',
#   'uncertain',
#   'management',
#   'condition',
#   'achieve',
#   'continuous',
#   'growth',
#   'caring',
#   'customer',
#   'taking',
#   'quick',
#   'action',
#   'seek',
#   'new',
#   'opportunity',
#   'even',
#   'moment',
#   'amorepacific',
#   'striving',
#   'satisfy',
#   'global',
#   'customer',
#   'discovering',
#   'value',
#   'sustainable',
#   'beauty',
#   'found',
#   'asia',
#   'profound',
#   'wisdom',
#   'also',
#   'making',
#   'concerted',
#   'effort',
#   'create',
#   'sustainable',
#   'company',
#   'amorepacific',
#   'ha',
#   'minimized',
#   'negative',
#   'impact',
#   'environment',
#   'strengthened',
#   'development',
#   'sustainable',
#   'product',
#   'packaging',
#   'material',
#   'deliver',
#   'value',
#   'environment',
#   'friendly',
#   'consumption',
#   'customer',
#   'continually',
#   'expanded',
#   'beautiful',
#   'fair',
#   'trade',
#   'acquire',
#   'outstanding',
#   'local',
#   'raw',
#   'material',
#   'support',
#   'local',
#   'community',
#   'concentrated',
#   'corporate',
#   'competency',
#   'developing',
#   'eco',
#   'friendly',
#   'package',
#   'used',
#   'botanical',
#   'raw',
#   'material',
#   'recycled',
#   'material',
#   'also',
#   'amorepacific',
#   'beauty',
#   'production',
#   'site',
#   'equipped',
#   'production',
#   'logistics',
#   'system',
#   'global',
#   'standard',
#   'acquired',
#   'certification',
#   'eco',
#   'friendly',
#   'building',
#   'cgmp',
#   'cosmetic',
#   'good',
#   'manufacturing',
#   'practice',
#   'constructed',
#   'botanical',
#   'garden',
#   'raw',
#   'material',
#   'environment',
#   'friendly',
#   'natural',
#   'park',
#   'based',
#   'effort',
#   'become',
#   'beauty',
#   'creator',
#   'world',
#   'providing',
#   'high',
#   'quality',
#   'product',
#   'best',
#   'raw',
#   'material',
#   'customer',
#   'contributing',
#   'environment',
#   'local',
#   'community',
#   'global',
#   'brand',
#   'company',
#   'amorepacific',
#   'seeking',
#   'achieve',
#   'realized',
#   'talented',
#   'people',
#   'ready',
#   'challenge',
#   'world',
#   'stage',
#   'therefore',
#   'amorepacific',
#   'ha',
#   'worked',
#   'towards',
#   'developing',
#   'global',
#   'competency',
#   'employee',
#   'based',
#   'management',
#   'philosophy',
#   'valuing',
#   'people',
#   'everything',
#   'else',
#   'creating',
#   'workplace',
#   'employee',
#   'grow',
#   'individual',
#   'smart',
#   'work',
#   'happy',
#   'plus',
#   'campaign',
#   'increased',
#   'employee',
#   'engagement',
#   'devoted',
#   'customer',
#   'helped',
#   'find',
#   'balance',
#   'work',
#   'personal',
#   'life',
#   'also',
#   'consolidate',
#   'dream',
#   'vocation',
#   'variety',
#   'talented',
#   'employee',
#   'one',
#   'implementing',
#   'corporate',
#   'culture',
#   'activity',
#   'one',
#   'amorepacific',
#   'global',
#   'perspective',
#   'amorepacific',
#   'ha',
#   'continually',
#   'strengthened',
#   'win',
#   'win',
#   'relationship',
#   'business',
#   'partner',
#   'create',
#   'healthy',
#   'business',
#   'ecosystem',
#   'strengthen',
#   'competitiveness',
#   'business',
#   'partner',
#   'expanded',
#   'supplier',
#   'support',
#   'fund',
#   'supplier',
#   'opened',
#   'win',
#   'win',
#   'portal',
#   'site',
#   'supplier',
#   'effectively',
#   'resolve',
#   'complaint',
#   'business',
#   'partner',
#   'result',
#   'amorepacific',
#   'business',
#   'partner',
#   'maintain',
#   'beautiful',
#   'relationship',
#   'help',
#   'achieve',
#   'growth',
#   'furthermore',
#   'order',
#   'fulfill',
#   'responsibility',
#   'global',
#   'citizen',
#   'support',
#   'ten',
#   'principle',
#   'un',
#   'global',
#   'compact',
#   'ungc',
#   'including',
#   'human',
#   'right',
#   'labor',
#   'environment',
#   'anticorruption',
#   'continually',
#   'work',
#   'towards',
#   'reflecting',
#   'principle',
#   'amorepacific',
#   'management',
#   'activity',
#   'stakeholder',
#   'management',
#   'policy',
#   'amorepacific',
#   '2013',
#   'team',
#   'together',
#   'show',
#   'amorepacific',
#   'commitment',
#   'look',
#   'apex',
#   'two',
#   'point',
#   'meet',
#   'together',
#   'instead',
#   'dividing',
#   'world',
#   'mine',
#   'others',
#   'thereby',
#   'walking',
#   'side',
#   'side',
#   'partner',
#   'business',
#   'ecosystem',
#   'including',
#   'supplier',
#   'furthermore',
#   'walk',
#   'together',
#   'world',
#   'society',
#   'grow',
#   'much',
#   'faster',
#   'healthier',
#   'amorepacific',
#   'ha',
#   'dream',
#   'changing',
#   'world',
#   'beauty',
#   'product',
#   'employee',
#   'amorepacific',
#   'make',
#   'concerted',
#   'effort',
#   'achieve',
#   'dream',
#   'become',
#   'company',
#   'customer',
#   'love',
#   'asia',
#   'thank',
#   'chairman',
#   'ceo',
#   'amorepacific',
#   'corporation',
#   'kyung',
#   'bae',
#   'suh'],
#  ['amorepacifc',
#   'group',
#   'endeavor',
#   'become',
#   'great',
#   'global',
#   'company',
#   'brings',
#   'brighter',
#   'future',
#   'next',
#   'generation',
#   'changing',
#   'world',
#   'beautiful',
#   'healthier',
#   'place',
#   'honoring',
#   'founder',
#   'philosophy',
#   'contributing',
#   'mankind',
#   'creating',
#   'beauty',
#   'health',
#   'technology',
#   'heartfelt',
#   'sincerity',
#   'amorepacific',
#   'group',
#   'ha',
#   'continued',
#   'journey',
#   'beauty',
#   'past',
#   '70',
#   'year',
#   'change',
#   'world',
#   'unique',
#   'asian',
#   'beauty',
#   'mission',
#   'spread',
#   'essence',
#   'asian',
#   'beauty',
#   'around',
#   'world',
#   'asian',
#   'beauty',
#   'creator',
#   'fully',
#   'devoted',
#   'discover',
#   'value',
#   'harmony',
#   'beauty',
#   'based',
#   'asian',
#   'wisdom',
#   'deliver',
#   'customer',
#   'world',
#   'despite',
#   'fast',
#   'changing',
#   'global',
#   'business',
#   'environment',
#   'economic',
#   'uncertainty',
#   'recent',
#   'year',
#   'never',
#   'ceased',
#   'grow',
#   'constantly',
#   'innovating',
#   'provide',
#   'better',
#   'product',
#   'service',
#   'based',
#   'voice',
#   'customer',
#   'always',
#   'reminding',
#   'stay',
#   'humble',
#   'learn',
#   'customer',
#   'today',
#   'success',
#   'could',
#   'possible',
#   'without',
#   'great',
#   'support',
#   'customer',
#   'well',
#   'society',
#   'working',
#   'together',
#   'nature',
#   'owe',
#   'next',
#   'generation',
#   'reason',
#   'engaged',
#   'various',
#   'sustainable',
#   'activity',
#   'order',
#   'promote',
#   'harmonious',
#   'co',
#   'existence',
#   'co',
#   'prosperity',
#   'customer',
#   'society',
#   'natural',
#   'environment',
#   'first',
#   'part',
#   'effort',
#   'established',
#   'implemented',
#   'strategy',
#   'minimize',
#   'social',
#   'environmental',
#   'impact',
#   'entire',
#   'life',
#   'cycle',
#   'product',
#   'technological',
#   'development',
#   'disposal',
#   'addition',
#   'maximize',
#   'customer',
#   'value',
#   'continuing',
#   'launch',
#   'innovative',
#   'product',
#   'consider',
#   'diverse',
#   'preference',
#   'shown',
#   'customer',
#   'around',
#   'world',
#   'offering',
#   'differentiated',
#   'shopping',
#   'experience',
#   'digital',
#   'innovation',
#   'second',
#   'engaging',
#   'various',
#   'green',
#   'activity',
#   'reduce',
#   'environmental',
#   'impact',
#   'corporate',
#   'activity',
#   'protect',
#   'planet',
#   'response',
#   'global',
#   'issue',
#   'climate',
#   'change',
#   'water',
#   'scarcity',
#   'trying',
#   'reduce',
#   'carbon',
#   'emission',
#   'water',
#   'consumption',
#   'also',
#   'strengthened',
#   'safety',
#   'environmental',
#   'management',
#   'system',
#   'also',
#   'made',
#   'effort',
#   'preserve',
#   'biodiversity',
#   'conducting',
#   'research',
#   'recovery',
#   'efficacy',
#   'rare',
#   'indigenous',
#   'plant',
#   'specie',
#   'third',
#   'reinforcing',
#   'win',
#   'win',
#   'relationship',
#   'executive',
#   'employee',
#   'partner',
#   'heightened',
#   'education',
#   'training',
#   'standard',
#   'foster',
#   'global',
#   'talent',
#   'enhance',
#   'competency',
#   'executive',
#   'employee',
#   'also',
#   'committed',
#   'creating',
#   'pleasant',
#   'working',
#   'environment',
#   'help',
#   'employee',
#   'maintain',
#   'good',
#   'balance',
#   'work',
#   'personal',
#   'life',
#   'meanwhile',
#   'ensure',
#   'harmonious',
#   'mutual',
#   'growth',
#   'business',
#   'partner',
#   'client',
#   'beauty',
#   'partner',
#   'strengthened',
#   'financial',
#   'educational',
#   'support',
#   'prepared',
#   'foundation',
#   'promote',
#   'open',
#   'communication',
#   'active',
#   'participation',
#   'fourth',
#   'responsible',
#   'corporate',
#   'citizen',
#   'dedicated',
#   'fulfilling',
#   'corporate',
#   'social',
#   'responsibility',
#   'helping',
#   'woman',
#   'member',
#   'local',
#   'community',
#   'realize',
#   'beautiful',
#   'healthy',
#   'life',
#   'thereby',
#   'creating',
#   'prosperous',
#   'society',
#   'spreading',
#   'value',
#   'beauty',
#   'three',
#   'area',
#   'woman',
#   'natural',
#   'ecosystem',
#   'culture',
#   'discover',
#   'create',
#   'new',
#   'value',
#   'shared',
#   'society',
#   'spread',
#   'value',
#   'beyond',
#   'national',
#   'border',
#   'across',
#   'whole',
#   'world',
#   'lastly',
#   'global',
#   'citizen',
#   'support',
#   'adhere',
#   '10',
#   'principle',
#   'un',
#   'global',
#   'compact',
#   'ungc',
#   'regarding',
#   'human',
#   'right',
#   'labor',
#   'environment',
#   'anti',
#   'corruption',
#   'continue',
#   'advance',
#   'respect',
#   'principle',
#   'management',
#   'practice',
#   'honorable',
#   'stakeholder',
#   '2015',
#   'meaningful',
#   'year',
#   'mark',
#   '70th',
#   'anniversary',
#   'amorepacific',
#   'group',
#   'foundation',
#   'also',
#   'time',
#   'transition',
#   '70',
#   'year',
#   'journey',
#   'ha',
#   'travelled',
#   'pond',
#   'stream',
#   'river',
#   'ha',
#   'finally',
#   'set',
#   'sail',
#   'greater',
#   'ocean',
#   'amorepacific',
#   'group',
#   'never',
#   'cease',
#   'effort',
#   'make',
#   'positive',
#   'impact',
#   'people',
#   'life',
#   'beauty',
#   'health',
#   'engage',
#   'sustainable',
#   'management',
#   'become',
#   'great',
#   'global',
#   'company',
#   'trusted',
#   'supported',
#   'customer',
#   'throughout',
#   'world',
#   'thank'],
#  ['amorepacific',
#   'group',
#   'ha',
#   'pursuing',
#   'path',
#   'beauty',
#   'last',
#   '70',
#   'year',
#   'respond',
#   'customer',
#   'high',
#   'expectation',
#   'product',
#   'service',
#   'answering',
#   'vocation',
#   'asian',
#   'beauty',
#   'creator',
#   'made',
#   'every',
#   'effort',
#   'transform',
#   'world',
#   'beauty',
#   'sharing',
#   'customer',
#   'stakeholder',
#   'unique',
#   'beauty',
#   'product',
#   'company',
#   'best',
#   'creating',
#   '2015',
#   'despite',
#   'global',
#   'economic',
#   'slowdown',
#   'outbreak',
#   'middle',
#   'east',
#   'respiratory',
#   'syndrome',
#   'mers',
#   'affected',
#   'social',
#   'corporate',
#   'activity',
#   'korea',
#   'continued',
#   'emphasize',
#   'innovation',
#   'retail',
#   'sale',
#   'global',
#   'expansion',
#   'result',
#   'able',
#   'celebrate',
#   '70th',
#   'anniversary',
#   'closer',
#   'ever',
#   'reaching',
#   'dream',
#   'becoming',
#   'great',
#   'global',
#   'brand',
#   'company',
#   'amorepacific',
#   'group',
#   'ha',
#   'journeyed',
#   'pond',
#   'stream',
#   'river',
#   'confluence',
#   'set',
#   'sail',
#   'upon',
#   'great',
#   'ocean',
#   'great',
#   'journey',
#   'across',
#   'ocean',
#   'cannot',
#   'made',
#   'alone',
#   'done',
#   'hastily',
#   'rather',
#   'shall',
#   'travel',
#   'hand',
#   'hand',
#   'others',
#   'endure',
#   'complete',
#   'far',
#   'reaching',
#   'journey',
#   'committed',
#   'fulfilling',
#   'responsibility',
#   'ethical',
#   'corporate',
#   'citizen',
#   'throughout',
#   'year',
#   'amorepacific',
#   'group',
#   'ha',
#   'undertaken',
#   'following',
#   'activity',
#   'employee',
#   'customer',
#   'stakeholder',
#   'environment',
#   'society',
#   'first',
#   'implementing',
#   'rigorous',
#   'strategy',
#   'designed',
#   'reduce',
#   'social',
#   'environmental',
#   'footprint',
#   'throughout',
#   'entire',
#   'lifecycle',
#   'product',
#   'research',
#   'development',
#   'end',
#   'user',
#   'stage',
#   'beauty',
#   'maestro',
#   'continue',
#   'maximize',
#   'customer',
#   'value',
#   'experience',
#   'continuing',
#   'launch',
#   'highly',
#   'competitive',
#   'innovative',
#   'product',
#   'reflecting',
#   'diverse',
#   'preference',
#   'customer',
#   'around',
#   'world',
#   'offer',
#   'differentiated',
#   'shopping',
#   'experience',
#   'digital',
#   'innovation',
#   'mobile',
#   'application',
#   'second',
#   'line',
#   'commitment',
#   'protecting',
#   'planet',
#   'undertaking',
#   'range',
#   'activity',
#   'preserve',
#   'nature',
#   'reduce',
#   'environmental',
#   'effect',
#   'corporate',
#   'activity',
#   'specifically',
#   'response',
#   'global',
#   'environmental',
#   'priority',
#   'climate',
#   'change',
#   'water',
#   'scarcity',
#   'emphasize',
#   'reducing',
#   'greenhouse',
#   'gas',
#   'emission',
#   'optimizing',
#   'water',
#   'use',
#   'systematically',
#   'improving',
#   'environmental',
#   'safety',
#   'measure',
#   'contribute',
#   'biodiversity',
#   'engage',
#   'activity',
#   'restore',
#   'rare',
#   'indigenous',
#   'plant',
#   'specie',
#   'third',
#   'strengthening',
#   'win',
#   'win',
#   'partnership',
#   'employee',
#   'business',
#   'partner',
#   'start',
#   'end',
#   'supply',
#   'chain',
#   'heightened',
#   'education',
#   'training',
#   'standard',
#   'foster',
#   'global',
#   'talent',
#   'enhance',
#   'global',
#   'professional',
#   'competency',
#   'employee',
#   'management',
#   'rolled',
#   'program',
#   'help',
#   'create',
#   'great',
#   'global',
#   'company',
#   'respect',
#   'work',
#   'life',
#   'balance',
#   'addition',
#   'ensure',
#   'win',
#   'win',
#   'growth',
#   'business',
#   'partner',
#   'expanded',
#   'financial',
#   'educational',
#   'support',
#   'prepared',
#   'foundation',
#   'upon',
#   'promote',
#   'open',
#   'communication',
#   'active',
#   'participation',
#   'fourth',
#   'responsible',
#   'corporate',
#   'citizen',
#   'supporting',
#   'various',
#   'program',
#   'enrich',
#   'life',
#   'woman',
#   'community',
#   'group',
#   'particular',
#   'corporate',
#   'social',
#   'responsibility',
#   'activity',
#   'focused',
#   'woman',
#   'natural',
#   'ecosystem',
#   'culture',
#   'aim',
#   'integrate',
#   'emphasis',
#   'healthy',
#   'beauty',
#   'creating',
#   'shared',
#   'value',
#   'business',
#   'society',
#   'worldwide',
#   'finally',
#   'global',
#   'citizen',
#   'support',
#   '10',
#   'principle',
#   'united',
#   'nation',
#   'global',
#   'compact',
#   'regarding',
#   'human',
#   'right',
#   'labor',
#   'environment',
#   'anti',
#   'corruption',
#   'putting',
#   'every',
#   'effort',
#   'fully',
#   'integrating',
#   'principle',
#   'corporate',
#   'strategy',
#   'operation',
#   'sustainable',
#   'business',
#   'practice',
#   'reflect',
#   'commitment',
#   'grand',
#   'vision',
#   'bring',
#   'happier',
#   'today',
#   'beautiful',
#   'tomorrow',
#   'customer',
#   'stakeholder',
#   'begun',
#   '70th',
#   'year',
#   'journey',
#   'transform',
#   'world',
#   'beauty',
#   'thank',
#   'showing',
#   'support',
#   'journey',
#   'count',
#   'continued',
#   'interest',
#   'engagement'],
#  ['year',
#   'mark',
#   '25th',
#   'anniversary',
#   'establishment',
#   'asiana',
#   'airline',
#   'since',
#   'embarked',
#   'journey',
#   'brighter',
#   'future',
#   'truly',
#   'grateful',
#   'stakeholder',
#   'loved',
#   'rooted',
#   'u',
#   'past',
#   '25',
#   'year',
#   'thanks',
#   'support',
#   'asiana',
#   'airline',
#   'wa',
#   'able',
#   'become',
#   '1st',
#   'airline',
#   'named',
#   'airline',
#   'year',
#   'five',
#   'consecutive',
#   'time',
#   'asiana',
#   'airline',
#   'ha',
#   'unwavering',
#   'commitment',
#   'responsibility',
#   'beautiful',
#   'company',
#   'creates',
#   'best',
#   'corporate',
#   'value',
#   'industry',
#   'achieving',
#   'customer',
#   'satisfaction',
#   'safest',
#   'superior',
#   'service',
#   'despite',
#   'adverse',
#   'external',
#   'condition',
#   'including',
#   'economic',
#   'recession',
#   'triggered',
#   'developed',
#   'country',
#   'spread',
#   'korea',
#   'asiana',
#   'airline',
#   'achieved',
#   'positive',
#   'performance',
#   'carrying',
#   '11million',
#   'passenger',
#   'year',
#   'generating',
#   'krw',
#   '5',
#   'trillion',
#   '638',
#   '1',
#   'billion',
#   'revenue',
#   'krw',
#   '132',
#   '5',
#   'billion',
#   'ebit',
#   'driven',
#   'part',
#   'growth',
#   'chinese',
#   'market',
#   'increasing',
#   'demand',
#   'leisure',
#   'activity',
#   '2012',
#   'addition',
#   'asiana',
#   'ha',
#   'continued',
#   'introducing',
#   'latest',
#   'equipment',
#   'facility',
#   'including',
#   'nine',
#   'passenger',
#   'jet',
#   'two',
#   'cargo',
#   'jet',
#   'operate',
#   'total',
#   '80',
#   'airplane',
#   'upgrading',
#   'plane',
#   'seat',
#   'facility',
#   'two',
#   'boeing',
#   '777',
#   'airplane',
#   'asiana',
#   'also',
#   'launched',
#   'flight',
#   'vladivostok',
#   'completing',
#   'triangle',
#   'route',
#   'far',
#   'east',
#   'connecting',
#   'flight',
#   'khabarovsk',
#   'sakhalin',
#   'increased',
#   'flight',
#   'haneda',
#   'hong',
#   'kong',
#   'honolulu',
#   'paris',
#   'increase',
#   'customer',
#   'convenience',
#   'parallel',
#   'asiana',
#   'airline',
#   'ha',
#   'introduced',
#   'wide',
#   'array',
#   'initiative',
#   'beautiful',
#   'world',
#   'create',
#   'prosperity',
#   'everyone',
#   'company',
#   'faithfully',
#   'complying',
#   '10',
#   'principle',
#   'un',
#   'global',
#   'compact',
#   'various',
#   'issue',
#   'human',
#   'right',
#   'labor',
#   'environment',
#   'anti',
#   'corruption',
#   'expanding',
#   'scope',
#   'eco',
#   'flight',
#   'distinct',
#   'green',
#   'operation',
#   'program',
#   'company',
#   'promoting',
#   'family',
#   'friendly',
#   'work',
#   'environment',
#   'inclusive',
#   'growth',
#   'also',
#   'making',
#   'remarkable',
#   'stride',
#   'social',
#   'contribution',
#   'initiative',
#   'go',
#   'beyond',
#   'national',
#   'boundary',
#   'donating',
#   'book',
#   'multi',
#   'cultural',
#   'family',
#   'korea',
#   'opening',
#   'beautiful',
#   'class',
#   'sister',
#   'school',
#   'china',
#   'launching',
#   'love',
#   'house',
#   'initiative',
#   'vietnam',
#   'strenuous',
#   'endeavor',
#   'ha',
#   'earned',
#   'asiana',
#   'recognition',
#   '1',
#   'airline',
#   'dow',
#   'jones',
#   'sustainability',
#   'index',
#   'four',
#   'consecutive',
#   'year',
#   'grand',
#   'prize',
#   '1st',
#   'family',
#   'friendly',
#   'employer',
#   'award',
#   '1',
#   'airline',
#   'korean',
#   'sustainability',
#   'index',
#   'going',
#   'forward',
#   'asiana',
#   'people',
#   'exert',
#   'best',
#   'endeavor',
#   'building',
#   'achievement',
#   'past',
#   '25',
#   'year',
#   'fly',
#   'beyond',
#   'competition',
#   'hope',
#   'stakeholder',
#   'continue',
#   'give',
#   'support',
#   'journey',
#   'towards',
#   'beautiful',
#   'future',
#   'thank'],
#  ['since',
#   'inception',
#   'asiana',
#   'airline',
#   'ha',
#   'pledged',
#   'practiced',
#   'highest',
#   'standard',
#   'safety',
#   'service',
#   'truly',
#   'satisfy',
#   'customer',
#   'best',
#   'safety',
#   'service',
#   'two',
#   'non',
#   'negotiable',
#   'core',
#   'value',
#   'capability',
#   'asiana',
#   'airline',
#   'always',
#   'strive',
#   'receive',
#   'strong',
#   'trust',
#   'customer',
#   'nowadays',
#   'aviation',
#   'industry',
#   'domestic',
#   'global',
#   'market',
#   'going',
#   'severe',
#   'competition',
#   'uncertainty',
#   'growing',
#   'due',
#   'persistently',
#   'high',
#   'oil',
#   'price',
#   'increased',
#   'volatility',
#   'exchange',
#   'rate',
#   'others',
#   'also',
#   'declining',
#   'market',
#   'share',
#   'fsc',
#   'full',
#   'service',
#   'carrier',
#   'due',
#   'aggressive',
#   'sale',
#   'strategy',
#   'lcc',
#   'low',
#   'cost',
#   'carrier',
#   'lackluster',
#   'performance',
#   'major',
#   'economy',
#   'dealing',
#   'double',
#   'whammy',
#   'circumstance',
#   'asiana',
#   'airline',
#   'ha',
#   'worked',
#   'really',
#   'hard',
#   'respond',
#   'external',
#   'change',
#   'flexibly',
#   'playing',
#   'strength',
#   'better',
#   'company',
#   'competitiveness',
#   '2013',
#   'asiana',
#   'airline',
#   'introduced',
#   'eight',
#   'new',
#   'aircraft',
#   'a330',
#   'a321',
#   'b777',
#   'etc',
#   'augment',
#   'aircraft',
#   'fleet',
#   'increased',
#   'gimpo',
#   'jeju',
#   'flight',
#   'accommodate',
#   'rapidly',
#   'increasing',
#   'chinese',
#   'tourist',
#   'flexibly',
#   'operating',
#   'flight',
#   'chicago',
#   'seattle',
#   'honolulu',
#   'regular',
#   'extra',
#   'cargo',
#   'flight',
#   'hong',
#   'kong',
#   'endeavor',
#   'increase',
#   'profitability',
#   'extending',
#   'partnership',
#   'expanding',
#   'sale',
#   'channel',
#   'internet',
#   'mobile',
#   'etc',
#   'leveraging',
#   'high',
#   'popularity',
#   'korean',
#   'culture',
#   'joint',
#   'marketing',
#   'campaign',
#   'safer',
#   'flight',
#   'operation',
#   'flight',
#   'crew',
#   'training',
#   'evaluation',
#   'scheme',
#   'ha',
#   'reinforced',
#   'safety',
#   'security',
#   'office',
#   'ha',
#   'upgraded',
#   'level',
#   'head',
#   'office',
#   'aviation',
#   'safety',
#   'expert',
#   'newly',
#   'hired',
#   'august',
#   '2013',
#   'asiana',
#   'airline',
#   'opened',
#   'second',
#   'hangar',
#   'incheon',
#   'ha',
#   'largest',
#   'ever',
#   'scale',
#   'cutting',
#   'edge',
#   'maintenance',
#   'facility',
#   'upgrade',
#   'corporate',
#   'capability',
#   'conduct',
#   'inspection',
#   'maintenance',
#   'time',
#   'measuring',
#   'global',
#   'standard',
#   'maintenance',
#   'quality',
#   'slogan',
#   'fly',
#   'together',
#   'beautiful',
#   'world',
#   'asiana',
#   'airline',
#   'ha',
#   'implemented',
#   'various',
#   'socially',
#   'responsible',
#   'initiative',
#   'based',
#   'four',
#   'core',
#   'topic',
#   'better',
#   'education',
#   'culture',
#   'sharing',
#   'green',
#   'management',
#   'art',
#   'culture',
#   'sponsorship',
#   'greener',
#   'earth',
#   'company',
#   'ha',
#   'introduced',
#   'airplane',
#   'better',
#   'fuel',
#   'efficiency',
#   'minimize',
#   'energy',
#   'consumption',
#   'driven',
#   'technologically',
#   'proven',
#   'co2',
#   'reduction',
#   'initiative',
#   'recognized',
#   'green',
#   'friendly',
#   'airline',
#   'also',
#   'take',
#   'care',
#   'precious',
#   'nature',
#   'earth',
#   'asiana',
#   'airline',
#   'successfully',
#   'overcame',
#   'internal',
#   'external',
#   'challenge',
#   '2013',
#   'improved',
#   'overall',
#   'business',
#   'efficiency',
#   'sustainable',
#   'growth',
#   'reinforced',
#   'business',
#   'competitiveness',
#   '2014',
#   'year',
#   'renew',
#   'determination',
#   'like',
#   'starting',
#   '2014',
#   'onwards',
#   'asiana',
#   'people',
#   'executive',
#   'employee',
#   'alike',
#   'fully',
#   'commit',
#   'continuing',
#   'sustainable',
#   'growth',
#   'increasing',
#   'contribution',
#   'environment',
#   'society',
#   'leveraging',
#   'company',
#   'financial',
#   'performance',
#   'hope',
#   'stakeholder',
#   'continue',
#   'give',
#   'support',
#   'encouragement',
#   'journey',
#   'towards',
#   'beautiful',
#   'future',
#   'thank'],
#  ['u',
#   'best',
#   'without',
#   'stopping',
#   'sustainable',
#   'growth',
#   'development',
#   'first',
#   'would',
#   'like',
#   'convey',
#   'sincere',
#   'appreciation',
#   'stakeholder',
#   'continued',
#   'affection',
#   'trust',
#   'last',
#   'year',
#   'able',
#   'reinforce',
#   'core',
#   'competency',
#   'competitiveness',
#   'motto',
#   'new',
#   'kumho',
#   'asiana',
#   'achievement',
#   'made',
#   'possible',
#   'assionnd',
#   'unwavering',
#   'focus',
#   'learned',
#   'early',
#   'year',
#   'chose',
#   'flawless',
#   'operational',
#   'safety',
#   'regaining',
#   'customer',
#   'trust',
#   'top',
#   'priority',
#   'safety',
#   'service',
#   'asiana',
#   'airline',
#   'highest',
#   'goal',
#   'made',
#   'improvement',
#   'flight',
#   'training',
#   'system',
#   'maintenance',
#   'quality',
#   'system',
#   'reinforce',
#   'general',
#   'safety',
#   'system',
#   'aisana',
#   'airline',
#   'ha',
#   'introduced',
#   'a380',
#   'next',
#   'generation',
#   'cutting',
#   'edge',
#   'aircraft',
#   'provide',
#   'convenience',
#   'customer',
#   'put',
#   'la',
#   'flight',
#   'order',
#   'reinforce',
#   'competitiveness',
#   'long',
#   'haul',
#   'flight',
#   'expanded',
#   'paris',
#   'istanbul',
#   'flight',
#   'furthermore',
#   'added',
#   'flight',
#   'guangzhou',
#   'yanji',
#   'shenzhen',
#   'take',
#   'dominance',
#   'leading',
#   'carrier',
#   'chinese',
#   'market',
#   'asiana',
#   'airline',
#   'ha',
#   'laid',
#   'groundwork',
#   'sustainability',
#   'revitalization',
#   'organizational',
#   'culture',
#   'smile',
#   'brings',
#   'blessing',
#   'campaign',
#   'meeting',
#   'executive',
#   'staffer',
#   'lead',
#   'frank',
#   'exchange',
#   'opinion',
#   'ha',
#   'given',
#   'u',
#   'sense',
#   'belonging',
#   'strong',
#   'bond',
#   'tearing',
#   'wall',
#   'position',
#   'asiana',
#   'airline',
#   'going',
#   'fulfill',
#   'management',
#   'policy',
#   'last',
#   'year',
#   'new',
#   'kumho',
#   'asiana',
#   '2015',
#   'try',
#   'best',
#   'reliable',
#   'beautiful',
#   'company',
#   'new',
#   'motto',
#   'strengthen',
#   'self',
#   'without',
#   'stopping',
#   'mean',
#   'ready',
#   'stand',
#   'one',
#   'work',
#   'tirelessly',
#   'steady',
#   'development',
#   'growth',
#   'company',
#   'addition',
#   'safety',
#   'service',
#   'item',
#   'already',
#   'promoted',
#   'integrated',
#   'safety',
#   'information',
#   'system',
#   'built',
#   'bold',
#   'investment',
#   'hi',
#   'tech',
#   'operation',
#   'equipment',
#   'made',
#   'continuously',
#   'strengthen',
#   'infrastructure',
#   'safety',
#   'also',
#   'enhance',
#   'foundation',
#   'bringing',
#   'awareness',
#   'safety',
#   'issue',
#   'order',
#   'reinforce',
#   'competitiveness',
#   'latest',
#   'aircraft',
#   'confirmed',
#   'plan',
#   'introduce',
#   'a350xwb',
#   'a321',
#   'neo',
#   'hope',
#   'help',
#   'build',
#   'foundation',
#   'future',
#   'growth',
#   'year',
#   'put',
#   'additional',
#   'a380s',
#   'new',
#   'york',
#   'flight',
#   'start',
#   'new',
#   'flight',
#   'rome',
#   'reinforce',
#   'competitiveness',
#   'long',
#   'haul',
#   'flight',
#   'also',
#   'speed',
#   'plan',
#   'add',
#   'strategic',
#   'air',
#   'route',
#   'china',
#   'asian',
#   'country',
#   'asiana',
#   'airline',
#   'hope',
#   'become',
#   'company',
#   'contributes',
#   'nation',
#   'society',
#   'social',
#   'environmental',
#   'activity',
#   'going',
#   'take',
#   'responsibility',
#   'social',
#   'environmental',
#   'issue',
#   'persistence',
#   'sincerity',
#   'one',
#   'effort',
#   'unicef',
#   'spare',
#   'coin',
#   'collection',
#   'ha',
#   'working',
#   'korean',
#   'committee',
#   'unicef',
#   'united',
#   'nation',
#   'child',
#   'fund',
#   'last',
#   'year',
#   'accumulated',
#   'amount',
#   'money',
#   'ha',
#   'exceeded',
#   '10',
#   'billion',
#   'fundraising',
#   'campaign',
#   'continued',
#   'benefit',
#   'underprivileged',
#   'child',
#   'also',
#   'activity',
#   'campaign',
#   'promote',
#   'corporate',
#   'responsibility',
#   'social',
#   'work',
#   'volunteering',
#   'relay',
#   'beautiful',
#   'classroom',
#   'china',
#   'tree',
#   'planting',
#   'event',
#   'reclaimed',
#   'land',
#   'near',
#   'metropolitan',
#   'area',
#   'various',
#   'environmental',
#   'activity',
#   'reduce',
#   'greenhouse',
#   'gas',
#   'retrospect',
#   'asiana',
#   'airline',
#   'ha',
#   'grown',
#   'evolved',
#   'thanks',
#   'stakeholder',
#   'continuous',
#   'affection',
#   'support',
#   'make',
#   'utmost',
#   'effort',
#   'raise',
#   'corporate',
#   'value',
#   'best',
#   'business',
#   'beautiful',
#   'company',
#   'willing',
#   'take',
#   'social',
#   'responsibility',
#   'raising',
#   'awareness',
#   'safety',
#   'issue',
#   'differentiating',
#   'service',
#   'distinct',
#   'idea',
#   'hope',
#   'stakeholder',
#   'favor',
#   'u',
#   'support',
#   'expectation',
#   'thank',
#   'soo',
#   'cheon',
#   'kim',
#   'president',
#   'ceo'],
#  ['first',
#   'would',
#   'like',
#   'express',
#   'heartfelt',
#   'gratitude',
#   'toward',
#   'everyone',
#   'provides',
#   'continuous',
#   'support',
#   'trust',
#   'u',
#   'asiana',
#   'airline',
#   'management',
#   'policy',
#   'focused',
#   'persistent',
#   'effort',
#   'past',
#   'year',
#   'asiana',
#   'airline',
#   'strove',
#   'become',
#   'beautiful',
#   'powerful',
#   'company',
#   'reinforcing',
#   'core',
#   'competence',
#   'well',
#   'restructuring',
#   'continuous',
#   'innovation',
#   'added',
#   'two',
#   'a380',
#   'aircraft',
#   'major',
#   'route',
#   'new',
#   'york',
#   'los',
#   'angeles',
#   'safe',
#   'comfortable',
#   'journey',
#   'customer',
#   'confirmed',
#   'plan',
#   'introduce',
#   'operate',
#   'aircraft',
#   'a350',
#   'mid',
#   'long',
#   'route',
#   'a32neo',
#   'short',
#   'route',
#   'order',
#   'establish',
#   'efficient',
#   'competitive',
#   'fleet',
#   'addition',
#   'launched',
#   'new',
#   'route',
#   'rome',
#   'astana',
#   'added',
#   'flight',
#   'chinese',
#   'city',
#   'including',
#   'yancheng',
#   'guilin',
#   'chongqing',
#   'chengdu',
#   'furthermore',
#   'launched',
#   'foqa',
#   'flight',
#   'operation',
#   'quality',
#   'assurance',
#   'committee',
#   'management',
#   'labor',
#   'participate',
#   'reinforced',
#   'evaluation',
#   'safety',
#   'team',
#   'flight',
#   'training',
#   'order',
#   'improve',
#   'quality',
#   'safety',
#   'flight',
#   'training',
#   'management',
#   'policy',
#   'asiana',
#   'airline',
#   'year',
#   '2016',
#   'summarized',
#   'back',
#   'founding',
#   'spirit',
#   'suggests',
#   'renew',
#   'asiana',
#   'airline',
#   'bringing',
#   'back',
#   'passion',
#   'determination',
#   'company',
#   'wa',
#   'founded',
#   'year',
#   'introduce',
#   'two',
#   'a380',
#   'aircraft',
#   'order',
#   'reinforce',
#   'competitiveness',
#   'long',
#   'distance',
#   'flight',
#   'total',
#   'six',
#   'a380s',
#   'air',
#   'seoul',
#   'wa',
#   'launched',
#   'earlier',
#   'year',
#   'cooperate',
#   'asiana',
#   'airline',
#   'air',
#   'busan',
#   'maximizing',
#   'synergy',
#   'effect',
#   'also',
#   'like',
#   'last',
#   'year',
#   'enhance',
#   'competitiveness',
#   'efficient',
#   'organizational',
#   'management',
#   'strategic',
#   'route',
#   'operation',
#   'improved',
#   'aircraft',
#   'competitiveness',
#   'enhanced',
#   'system',
#   'well',
#   'continue',
#   'establish',
#   'sustainable',
#   'base',
#   'invest',
#   'safety',
#   'integrated',
#   'safety',
#   'management',
#   'system',
#   'etc',
#   'planning',
#   'engage',
#   'actively',
#   'reducing',
#   'energy',
#   'consumption',
#   'greenhouse',
#   'gas',
#   'emission',
#   'optimizing',
#   'fuel',
#   'use',
#   'reducing',
#   'flight',
#   'fuel',
#   'cost',
#   'cleaning',
#   'engine',
#   'strive',
#   'perform',
#   'role',
#   'beautiful',
#   'company',
#   'sharing',
#   'talent',
#   'knowledge',
#   'asiana',
#   'airline',
#   'staff',
#   'social',
#   'responsibility',
#   'brand',
#   'beautiful',
#   'classroom',
#   'themed',
#   'activity',
#   'believe',
#   'value',
#   'corporation',
#   'top',
#   'industry',
#   'doe',
#   'lie',
#   'simply',
#   'making',
#   'profit',
#   'sharing',
#   'stakeholder',
#   'moving',
#   'forward',
#   'staff',
#   'asiana',
#   'airline',
#   'continue',
#   'make',
#   'effort',
#   'grow',
#   'beautiful',
#   'company',
#   'trusted',
#   'practice',
#   'sustainable',
#   'growth',
#   'hope',
#   'see',
#   'continuous',
#   'support',
#   'trust',
#   'long',
#   'time',
#   'thank'],
#  ['since',
#   'establishment',
#   'busan',
#   'bank',
#   '1967',
#   'ha',
#   'matured',
#   'local',
#   'region',
#   'bnk',
#   'financial',
#   'group',
#   'wa',
#   'launched',
#   '2011',
#   'group',
#   'ha',
#   'leaped',
#   'higher',
#   'korea',
#   'representative',
#   'regional',
#   'financial',
#   'group',
#   'seven',
#   'affiliate',
#   'space',
#   'merely',
#   'four',
#   'year',
#   'incorporation',
#   'kyongnam',
#   'bank',
#   'last',
#   'october',
#   'established',
#   'two',
#   'bank',
#   'system',
#   'result',
#   'solidified',
#   'presence',
#   'one',
#   'korea',
#   'top',
#   'five',
#   'financial',
#   'group',
#   'total',
#   'asset',
#   'krw',
#   '93',
#   'trillion',
#   '8',
#   '000',
#   'employee',
#   '500',
#   'branch',
#   'end',
#   '2014',
#   'corporate',
#   'title',
#   'wa',
#   'changed',
#   'b',
#   'financial',
#   'group',
#   'bnk',
#   'financial',
#   'group',
#   'b',
#   'might',
#   'understood',
#   'geographically',
#   'confined',
#   'busan',
#   'bnk',
#   'acronym',
#   'beyond',
#   '1',
#   'korea',
#   'busan',
#   'kyongnam',
#   'push',
#   'u',
#   'move',
#   'forward',
#   'become',
#   'global',
#   'super',
#   'regional',
#   'financial',
#   'group',
#   'intensified',
#   'scope',
#   'depth',
#   'happiness',
#   'project',
#   'ha',
#   'cemented',
#   'presence',
#   'iconic',
#   'brand',
#   'bnk',
#   'financial',
#   'group',
#   'leading',
#   'socially',
#   'responsible',
#   'management',
#   'practice',
#   'financial',
#   'sector',
#   '2012',
#   'committed',
#   'practicing',
#   'noblesse',
#   'oblige',
#   'befitting',
#   'higher',
#   'prestige',
#   'bnk',
#   'financial',
#   'group',
#   'year',
#   'corporate',
#   'slogan',
#   'bnk',
#   'financial',
#   'group',
#   'giving',
#   'hope',
#   'happiness',
#   'accordingly',
#   'plan',
#   'extend',
#   'financial',
#   'service',
#   'give',
#   'hope',
#   'local',
#   'community',
#   'customer',
#   'scaling',
#   'creative',
#   'finance',
#   'initiating',
#   'region',
#   'focused',
#   'social',
#   'contribution',
#   'project',
#   'story',
#   'tell',
#   'touch',
#   'heart',
#   'people',
#   'aim',
#   'create',
#   'exclusive',
#   'differentiated',
#   'value',
#   'selecting',
#   'following',
#   'action',
#   'plan',
#   'according',
#   'management',
#   'principle',
#   'great',
#   'innovation',
#   '2015',
#   'forward',
#   'looking',
#   'management',
#   'system',
#   'order',
#   'establish',
#   'basis',
#   'sustainable',
#   'growth',
#   'first',
#   'secure',
#   'engine',
#   'sustainable',
#   'growth',
#   'carrying',
#   'distinctive',
#   'strategy',
#   'establish',
#   'unparalleled',
#   'stature',
#   'leading',
#   'regional',
#   'financial',
#   'group',
#   'boost',
#   'role',
#   'financial',
#   'group',
#   'specialized',
#   'busan',
#   'mecca',
#   'finance',
#   'seeking',
#   'tap',
#   'oversea',
#   'market',
#   'group',
#   'future',
#   'growth',
#   'engine',
#   'lie',
#   'initiate',
#   'optimized',
#   'business',
#   'model',
#   'strategy',
#   'asia',
#   'cross',
#   'affiliate',
#   'collaboration',
#   'enable',
#   'business',
#   'localization',
#   'preemptive',
#   'manner',
#   'second',
#   'concentrate',
#   'intensifying',
#   'profitability',
#   'management',
#   'efficiency',
#   'based',
#   'solid',
#   'management',
#   'driven',
#   'stable',
#   'growth',
#   'based',
#   'strategy',
#   'focus',
#   'profitability',
#   'soundness',
#   'effort',
#   'underway',
#   'boost',
#   'competency',
#   'affiliate',
#   'exploring',
#   'new',
#   'business',
#   'affiliate',
#   'diversifying',
#   'income',
#   'source',
#   'maximizing',
#   'synergy',
#   'establishing',
#   'profit',
#   'oriented',
#   'organization',
#   'lastly',
#   'practice',
#   'distinctive',
#   'socially',
#   'responsible',
#   'management',
#   'serve',
#   'trusted',
#   'financial',
#   'partner',
#   'dramatically',
#   'upgrade',
#   'happiness',
#   'project',
#   'ha',
#   'maintained',
#   'past',
#   'three',
#   'year',
#   'take',
#   'lead',
#   'creating',
#   'value',
#   'shared',
#   'financial',
#   'industry',
#   'project',
#   'support',
#   'creative',
#   'finance',
#   'facilitation',
#   'regional',
#   'economy',
#   'including',
#   'technology',
#   'financing',
#   'relationship',
#   'finance',
#   'job',
#   'creation',
#   'explored',
#   'initiated',
#   'utmost',
#   'fulfill',
#   'social',
#   'responsibility',
#   'regional',
#   'community',
#   'resident',
#   'bnk',
#   'financial',
#   'group',
#   'promise',
#   'rise',
#   'exemplary',
#   'holding',
#   'company',
#   'model',
#   'ha',
#   'grown',
#   'world',
#   'class',
#   'financial',
#   'group',
#   'originating',
#   'local',
#   'region',
#   'driven',
#   'core',
#   'value',
#   'dynamic',
#   'glocal',
#   'partnership',
#   'symbolized',
#   'bnk',
#   'new',
#   'ci',
#   'management',
#   'motto',
#   'grow',
#   'higher',
#   'e',
#   'world',
#   'region',
#   'better',
#   'future',
#   'customer',
#   'would',
#   'like',
#   'express',
#   'thanks',
#   'stakeholder',
#   'customer',
#   'shareholder',
#   'local',
#   'community',
#   'continuous',
#   'interest',
#   'support',
#   'bnk',
#   'financial',
#   'group',
#   'sustainable',
#   'growth'],
#  ['march',
#   '2011',
#   'bnk',
#   'financial',
#   'group',
#   'wa',
#   'launched',
#   'financial',
#   'holding',
#   'company',
#   'first',
#   'time',
#   'regional',
#   'bank',
#   'incorporated',
#   'kyongnam',
#   'bank',
#   'affiliate',
#   '2014',
#   'bnk',
#   'asset',
#   'management',
#   'another',
#   'affiliate',
#   '2015',
#   'thereby',
#   'comprising',
#   'eight',
#   'affiliate',
#   'total',
#   'asset',
#   'krw',
#   '100',
#   'trillion',
#   'established',
#   'presence',
#   'ranked',
#   'korea',
#   'fifth',
#   'largest',
#   'financial',
#   'group',
#   'bnk',
#   'financial',
#   'group',
#   'wa',
#   'incorporated',
#   'asia',
#   'pacific',
#   'index',
#   'world',
#   'renowned',
#   'dow',
#   'jones',
#   'sustainability',
#   'index',
#   'djsi',
#   'associated',
#   'sustainability',
#   'moreover',
#   'ranked',
#   '178th',
#   'among',
#   'world',
#   'top',
#   '250',
#   'safest',
#   'bank',
#   '3rd',
#   'among',
#   'domestic',
#   'bank',
#   'banker',
#   'thereby',
#   'indicating',
#   'acceptance',
#   'korea',
#   'representative',
#   'financial',
#   'group',
#   'would',
#   'like',
#   'extend',
#   'gratitude',
#   'customer',
#   'shareholder',
#   'community',
#   'upholding',
#   'consistent',
#   'trust',
#   'love',
#   'company',
#   'seek',
#   'turn',
#   'current',
#   'management',
#   'environment',
#   'financial',
#   'paradigm',
#   'rapidly',
#   'changing',
#   'opportunity',
#   'development',
#   'group',
#   'plan',
#   'return',
#   'encouragement',
#   'love',
#   'u',
#   'successfully',
#   'achieving',
#   'vision',
#   '2020',
#   'global',
#   'best',
#   'regional',
#   'financial',
#   'group',
#   'mid',
#   'long',
#   'term',
#   'management',
#   'plan',
#   'announced',
#   'january',
#   '2016',
#   'set',
#   'great',
#   'innovation',
#   '2016',
#   'establishing',
#   'system',
#   'profit',
#   'oriented',
#   'sustainable',
#   'growth',
#   'management',
#   'measure',
#   'plan',
#   'proceed',
#   'following',
#   'strategic',
#   'task',
#   'intensively',
#   '2016',
#   'take',
#   'first',
#   'step',
#   'grow',
#   'higher',
#   'one',
#   'asia',
#   'top',
#   '40',
#   'financial',
#   'group',
#   '2020',
#   'first',
#   'solidify',
#   'system',
#   'sustainable',
#   'growth',
#   'great',
#   'innovation',
#   'launching',
#   'sum',
#   'bank',
#   'mobile',
#   'bank',
#   'group',
#   'level',
#   'last',
#   'march',
#   'dramatically',
#   'strengthened',
#   'group',
#   'future',
#   'competitiveness',
#   'establishing',
#   'customer',
#   'oriented',
#   'business',
#   'face',
#   'face',
#   'non',
#   'face',
#   'face',
#   'omni',
#   'channel',
#   'using',
#   'fin',
#   'tech',
#   'including',
#   'big',
#   'data',
#   'non',
#   'face',
#   'face',
#   'certification',
#   'also',
#   'beef',
#   'fundamental',
#   'group',
#   'turn',
#   'crisis',
#   'opportunity',
#   'continued',
#   'efficiency',
#   'corporate',
#   'management',
#   'second',
#   'secure',
#   'differentiated',
#   'basis',
#   'growth',
#   'exclusive',
#   'bnk',
#   'financial',
#   'group',
#   'gathering',
#   'competency',
#   'affiliate',
#   'maximize',
#   'cross',
#   'affiliate',
#   'synergy',
#   'throughout',
#   'business',
#   'group',
#   'level',
#   'strengthening',
#   'group',
#   'role',
#   'control',
#   'tower',
#   'take',
#   'closer',
#   'step',
#   'completing',
#   'financial',
#   'triangle',
#   'asia',
#   'mid',
#   'long',
#   'term',
#   'vision',
#   'global',
#   'business',
#   'implementing',
#   'success',
#   'model',
#   'overseas',
#   'market',
#   'entry',
#   'especially',
#   'focusing',
#   'busan',
#   'bank',
#   'bnk',
#   'capital',
#   'lastly',
#   'take',
#   'lead',
#   'creating',
#   'world',
#   'love',
#   'spearheading',
#   'socially',
#   'responsible',
#   'management',
#   'financial',
#   'sector',
#   'establish',
#   'systematic',
#   'strategy',
#   'socially',
#   'responsible',
#   'management',
#   'initiate',
#   'expansion',
#   'differentiated',
#   'social',
#   'contribution',
#   'project',
#   'upgrade',
#   'happy',
#   'finance',
#   'project',
#   'carried',
#   'since',
#   '2012',
#   'enhance',
#   'customer',
#   'happiness',
#   'trust',
#   'fully',
#   'enforcing',
#   'righteousness',
#   'ethical',
#   'management',
#   'well',
#   'protection',
#   'financial',
#   'consumer',
#   'required',
#   'financial',
#   'group',
#   'promise',
#   'bnk',
#   'financial',
#   'group',
#   'proactively',
#   'practice',
#   'sustainability',
#   'nurture',
#   'happiness',
#   'diverse',
#   'stakeholder',
#   'including',
#   'customer',
#   'shareholder',
#   'based',
#   'management',
#   'motto',
#   'world',
#   'region',
#   'better',
#   'future',
#   'customer',
#   'ask',
#   'unwavering',
#   'support',
#   'encouragement',
#   'u',
#   'leap',
#   'higher',
#   'asia',
#   'top',
#   '40',
#   'global',
#   'best',
#   'regional',
#   'financial',
#   'group',
#   '2020',
#   'thank',
#   'june'],
#  ['pleased',
#   'introduce',
#   'various',
#   'sustainable',
#   'management',
#   'activity',
#   'busan',
#   'port',
#   'authority',
#   'bpa',
#   'publishing',
#   'first',
#   'sustainability',
#   'report',
#   'since',
#   'founding',
#   '2004',
#   'bpa',
#   'ha',
#   'played',
#   'pivotal',
#   'role',
#   'developing',
#   'managing',
#   'operating',
#   'busan',
#   'port',
#   'make',
#   'one',
#   'world',
#   'best',
#   'hub',
#   'port',
#   'bpa',
#   'ha',
#   'contributed',
#   'developing',
#   'national',
#   'economy',
#   'strived',
#   'provide',
#   'customer',
#   'best',
#   'quality',
#   'service',
#   'carrying',
#   'major',
#   'project',
#   'construction',
#   'busan',
#   'new',
#   'port',
#   'redevelopment',
#   'north',
#   'port',
#   'global',
#   'shipping',
#   'industry',
#   'ha',
#   'faced',
#   'various',
#   'challenge',
#   'appearance',
#   'new',
#   'carrier',
#   'enlargement',
#   'vessel',
#   'intensified',
#   'competition',
#   'among',
#   'major',
#   'port',
#   'bpa',
#   'ha',
#   'proactively',
#   'taken',
#   'appropriate',
#   'measure',
#   'establishing',
#   'marketing',
#   'strategy',
#   'alliance',
#   'opening',
#   'representative',
#   'office',
#   'europe',
#   'conducting',
#   'customized',
#   'marketing',
#   'activity',
#   'shipping',
#   'company',
#   'thanks',
#   'ceaseless',
#   'effort',
#   'bpa',
#   'ha',
#   'achieved',
#   'surplus',
#   'net',
#   'income',
#   '11',
#   'consecutive',
#   'year',
#   'placed',
#   '6th',
#   'largest',
#   'port',
#   'term',
#   'cargo',
#   'volume',
#   'handling',
#   '18',
#   '68',
#   'million',
#   'container',
#   '2014',
#   'bpa',
#   '3rd',
#   'largest',
#   'port',
#   'handling',
#   '942',
#   'cargo',
#   'transshipment',
#   'demonstrates',
#   'global',
#   'competitiveness',
#   'shipping',
#   'industry',
#   'bpa',
#   'wa',
#   'selected',
#   'best',
#   'public',
#   'corporation',
#   'improving',
#   'slack',
#   'management',
#   'significantly',
#   'reforming',
#   'welfare',
#   'benefit',
#   'scheme',
#   'addition',
#   'recognized',
#   'best',
#   'public',
#   'corporation',
#   'assessment',
#   'comprehensive',
#   'integrity',
#   'anti',
#   'corruption',
#   'civil',
#   'right',
#   'commission',
#   'two',
#   'consecutive',
#   'year',
#   'performance',
#   'ha',
#   'allowed',
#   'u',
#   'gain',
#   'solid',
#   'trust',
#   'people',
#   'moreover',
#   'reinforced',
#   'fairness',
#   'transparency',
#   'transaction',
#   'improving',
#   'relevant',
#   'system',
#   'achieved',
#   'shared',
#   'growth',
#   'promoting',
#   'cooperation',
#   'business',
#   'partner',
#   'supporting',
#   'sale',
#   'channel',
#   'expansion',
#   'upgrading',
#   'business',
#   'environment',
#   'part',
#   'strategy',
#   'transforming',
#   'busan',
#   'port',
#   'green',
#   'port',
#   'bpa',
#   'ha',
#   'carried',
#   'e',
#   'rtgc',
#   'project',
#   'since',
#   '2007',
#   'changing',
#   'energy',
#   'source',
#   'tire',
#   'type',
#   'yard',
#   'crane',
#   'rtgc',
#   'diesel',
#   'electricity',
#   'aim',
#   'reducing',
#   'amount',
#   'pollutant',
#   'discharged',
#   'process',
#   'cargo',
#   'handling',
#   'furthermore',
#   'bpa',
#   'started',
#   'test',
#   'operation',
#   'replace',
#   'energy',
#   'source',
#   'yard',
#   'tractor',
#   'diesel',
#   'lng',
#   'order',
#   'make',
#   'busan',
#   'port',
#   'environmentally',
#   'friendly',
#   'introduction',
#   'environmental',
#   'ship',
#   'index',
#   'esi',
#   'bpa',
#   'induces',
#   'voluntary',
#   'participation',
#   'shipping',
#   'company',
#   'reducing',
#   'port',
#   'entry',
#   'departure',
#   'fee',
#   'based',
#   'eco',
#   'friendly',
#   'index',
#   'vessel',
#   'entering',
#   'busan',
#   'port',
#   'environmental',
#   'achievement',
#   'include',
#   'obtaining',
#   'certification',
#   'eco',
#   'friendly',
#   'building',
#   'international',
#   'passenger',
#   'terminal',
#   'recycling',
#   'waste',
#   'process',
#   'port',
#   'construction',
#   'aspect',
#   'social',
#   'activity',
#   'bpa',
#   'launched',
#   'social',
#   'contribution',
#   'brand',
#   'happy',
#   'ocean',
#   'raise',
#   'public',
#   'awareness',
#   'social',
#   'contribution',
#   'activity',
#   'conducted',
#   'various',
#   'activity',
#   'suitable',
#   'characteristic',
#   'marine',
#   'sport',
#   'experience',
#   'camp',
#   'youth',
#   'busan',
#   'port',
#   'love',
#   'event',
#   'integrated',
#   'safety',
#   'experience',
#   'event',
#   'youth',
#   'extensive',
#   'effort',
#   'bpa',
#   'ha',
#   'grand',
#   'prize',
#   'education',
#   'contribution',
#   'korea',
#   'ministry',
#   'education',
#   'mecenat',
#   'tower',
#   'award',
#   'busan',
#   'metropolitan',
#   'city',
#   'three',
#   'consecutive',
#   'year',
#   'ha',
#   'highly',
#   'recognized',
#   'excellence',
#   'social',
#   'contribution',
#   'activity',
#   'aim',
#   'achieving',
#   'qualitative',
#   'growth',
#   'generate',
#   'added',
#   'value',
#   'bpa',
#   'leap',
#   'forward',
#   'become',
#   'prestigious',
#   'port',
#   'realizing',
#   'busan',
#   'port',
#   'vision',
#   '2030',
#   'vision',
#   'includes',
#   'solidifying',
#   'status',
#   'world',
#   '3rd',
#   'largest',
#   'transshipment',
#   'port',
#   'increasing',
#   'proportion',
#   'transshipment',
#   '60',
#   'generating',
#   'regional',
#   'economic',
#   'impact',
#   'worth',
#   'krw',
#   '7',
#   '7',
#   'trillion',
#   'nurturing',
#   'various',
#   'kind',
#   'port',
#   'business',
#   'pursuit',
#   'new',
#   'vision',
#   'bpa',
#   'reinforce',
#   'social',
#   'responsibility',
#   'various',
#   'sector',
#   'social',
#   'contribution',
#   'also',
#   'integrity',
#   'ethical',
#   'management',
#   'port',
#   'safety',
#   'shared',
#   'growth',
#   'solidifying',
#   'leading',
#   'role',
#   'public',
#   'corporation',
#   'maintain',
#   'status',
#   'global',
#   'hub',
#   'port',
#   'bpa',
#   'overcome',
#   'challenge',
#   'environment',
#   'also',
#   'share',
#   'higher',
#   'value',
#   'stakeholder',
#   'continuously',
#   'carrying',
#   'innovation']]

# %%
from collections import Counter 

tokens = []
for text in preprocessed_texts: 
    tokens.extend(text)
    
counted_tokens = Counter(tokens) # 전처리된 토큰리스트를 카운팅 함
top_20 = counted_tokens.most_common(20)   
top_20
# Out:
# [('business', 1534),
#  ('company', 1445),
#  ('year', 1159),
#  ('management', 969),
#  ('global', 953),
#  ('growth', 938),
#  ('sustainability', 907),
#  ('customer', 890),
#  ('also', 766),
#  ('value', 755),
#  ('new', 752),
#  ('community', 722),
#  ('world', 713),
#  ('ha', 700),
#  ('product', 683),
#  ('social', 669),
#  ('employee', 658),
#  ('stakeholder', 651),
#  ('effort', 637),
#  ('u', 635)]

# %%
import pandas as pd 

pd.read_excel('./data/samsung_smartphone.xlsx')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             뉴스 식별자        일자     언론사             기고자  \
# 0     1.100201e+06  20220307    국민일보             양한주
# 1     2.100701e+06  20220307   헤럴드경제          박혜림 기자
# 2     2.100311e+06  20220307    서울경제          윤민혁 기자
# 3     1.100611e+06  20220307    서울신문             나상현
# 4     7.100501e+06  20220307    전자신문  전자신문인터넷 양민하 기자
# ...            ...       ...     ...             ...
# 1275  1.100401e+06  20211207    동아일보             서형석
# 1276  2.100101e+06  20211207    매일경제     이승훈,오찬종,박재영
# 1277  1.500051e+06  20211207    경남신문            연합뉴스
# 1278  2.100501e+06  20211207  파이낸셜뉴스             이보미
# 1279  2.100501e+06  20211207  파이낸셜뉴스             김준혁
#
#                                           제목     통합 분류1      통합 분류2  \
# 0       삼성, 중저가 시장서 명예회복 노린다 A시리즈로 아이폰SE와 격돌  IT_과학>모바일   IT_과학>콘텐츠
# 1             “삼성, 정말 이래도 돼?” 싸다고 ‘이것’까지 없앤다  IT_과학>모바일   IT_과학>콘텐츠
# 2             삼성전자, '랩서스' 해킹 관해 "고객정보 유출 없어"   IT_과학>보안   IT_과학>모바일
# 3            삼성 “해킹 자료에 임직원 고객 개인 정보 포함 안됐다”   IT_과학>보안   IT_과학>모바일
# 4         "갤럭시A 붙자"...공개 임박 애플 '아이폰SE3' 스펙은?  IT_과학>모바일         NaN
# ...                                      ...        ...         ...
# 1275        반도체 값 상승에 삼성 차기폰, 2년만에 가격 올릴 가능성      경제>유통      경제>자동차
# 1276                 이재용 '뉴삼성' 대표 3명 전원 교체할듯  IT_과학>모바일         NaN
# 1277                삼성 갤럭시S22 가격 3년 만에 인상될 듯      경제>유통      경제>자동차
# 1278       대세폰 나올때마다 5G 가입자 '쑥' 연내 2000만명 무난  IT_과학>모바일   경제>금융_재테크
# 1279  3분기 최다 판매폰은 '갤플립3', 삼성 국내 스마트폰 점유율 85%  IT_과학>모바일    경제>산업_기업
#
#           통합 분류3 사건/사고 분류1 사건/사고 분류2  사건/사고 분류3  \
# 0            NaN       NaN       NaN        NaN
# 1            NaN       NaN       NaN        NaN
# 2            NaN       NaN       NaN        NaN
# 3            NaN       NaN       NaN        NaN
# 4            NaN       NaN       NaN        NaN
# ...          ...       ...       ...        ...
# 1275   IT_과학>모바일       NaN       NaN        NaN
# 1276         NaN       NaN       NaN        NaN
# 1277   IT_과학>모바일       NaN       NaN        NaN
# 1278   IT_과학>콘텐츠       NaN       NaN        NaN
# 1279       경제>유통       NaN       NaN        NaN
#
#                                  인물      위치  \
# 0                               NaN      중국
# 1                               NaN     NaN
# 2                               NaN      미국
# 3                               NaN  미국,토렌트
# 4                               NaN      양산
# ...                             ...     ...
# 1275                            NaN   미국,대만
# 1276  한종희,노태문,이재용,경계현,고동진,이,김기남,김현석      미국
# 1277                            NaN     NaN
# 1278                            NaN      한국
# 1279                            NaN      한국
#
#                                               기관  \
# 0                                 애플,옴디아,삼성전자,삼성
# 1                                애플,샘모바일,유럽,삼성전자
# 2                      시큐리티팀,랩서스,퀄컴,삼성전자,MX,엔비디아
# 3                   랩서스,시큐리티팀,삼성전자,삼성,MX사업부,엔비디아
# 4         궈밍치,애플,전자신문,JP모건,퀄컴,옴디아,삼성전자,GSM아레나,삼성
# ...                                          ...
# 1275          TSMC,애플,미디어텍,정보통신,퀄컴,삼성전자,삼성,트라,AP
# 1276                            삼성전자,삼성전기,뉴삼성,삼성
# 1277                      정보통신,삼성전자,GSM아레나,한국,삼성
# 1278  과학기술정보통신부,애플,SK텔레콤,KT,삼성전자,LG유플러스,삼성,과기정통부
# 1279                             애플,삼성전자,LG전자,삼성
#
#                                                     키워드  \
# 0     삼성,중저,시장,명예회복,A시리즈,아이폰SE,격돌,삼성전자,공개,이달,갤럭시,시리즈...
# 1     삼성,충전기,삼성전자,구성품,중저가,스마트폰,충전기,불포함,충전기,어댑터,A13,시...
# 2     삼성전자,랩서스,해킹,고객,정보,유출,삼성전자,외국,해커,그룹,랩서스,APSUS,해...
# 3     자료,삼성,해킹,임직원,고객,포함,개인,정보,삼성전자,랩서스,외국,해커,그룹,APS...
# 4     아이폰SE3,갤럭시,공개,임박,애플,아이폰,SE,스펙,애플,이벤트,스페셜,아이폰SE...
# ...                                                 ...
# 1275  반도체,상승,반도체,삼성,차기폰,2년,가격,가능성,갤럭시S22,내년,출시,예상,갤럭...
# 1276  이재용,뉴삼성,대표,교체,전원,삼성전자,대표,이사,전면,교체,인사,단행,업계,삼성전...
# 1277  삼성,갤럭시,가격,인상,반도체,대란,100만,원대,예상,세계적,반도체,대란,장기화,...
# 1278  대세폰,가입자,연내,무난,아이폰,출시,10월,이통,순증,가입,Z시리즈,삼성,폴더블폰...
# 1279  판매폰,최다,갤플립3,삼성,애플,분기,5%P,감소,삼성전자,3,스마트폰,점유,85%...
#
#                                       특성추출(가중치순 상위 50개)  \
# 0     갤럭시,삼성전자,스마트폰,중저가,gos,업데이트,5g,옴디아,점유율,바이오닉,출하량...
# 1     갤럭시,충전기,스마트폰,삼성전자,중저가폰,중저가,샘모바일,구성품,a13,어댑,후속작...
# 2     삼성전자,랩서스,삼성,임직원,하드웨어,미국,트러스트존,사업부,보안시스템,그래픽카드,...
# 3     삼성전자,임직원,랩서스,미국,엔비디아,사업부,보안시스템,소스코드,토렌트,회로도,그래...
# 4     중저가,스마트폰,아이폰se3,갤럭시,삼성전자,출하량,사용자,64gb,상반기,옴디아,...
# ...                                                 ...
# 1275  갤럭시,스마트폰,삼성전자,충전기,반도체,ap,파운드리,대만,기본형,사업부,12만,1...
# 1276  삼성전자,부회장,사장단,부사장,사업부,대표이사,갤럭시,사업부장,이재용,미국,삼성전기...
# 1277  갤럭시,삼성전자,반도체,100만,기본형,자릿수,s22,124만,139만,s21,99...
# 1278  가입자,5g,순증,폴더블폰,lte,갤럭시,스마트폰,삼성전자,이동통신3사,97만,2000만
# 1279  갤럭시,스마트폰,삼성,플립,점유율,카운터포인트리서치,4위,공급난,반도체,한국,갤럭시...
#
#                                                      본문  \
# 0     삼성전자가 이르면 이달 중 보급형 스마트폰인 갤럭시 A 시리즈를 선보인다. 2년 만...
# 1     [헤럴드경제=박혜림 기자] “싸다고 충전기까지 뺀다?” \n \n 삼성전자가 중저가...
# 2     삼성전자(005930)가 외국 해커 그룹 ‘랩서스(LAPSUS＄)’로부터 해킹 당했...
# 3     삼성전자가 최근 외국 해커그룹 랩서스(LAPSUS$)로부터 해킹 공격을 받은 것과 ...
# 4     애플이 오는 9일 스페셜 이벤트를 통해 '아이폰SE' 신제품을 선보일 전망이다. 홈...
# ...                                                 ...
# 1275  반도체를 비롯한 스마트폰 부품 값 상승 여파로 삼성전자가 차기 전략 스마트폰 가격을...
# 1276  삼성전자가 대표이사 3명을 전면 교체하는 인사를 단행한다. 업계에 따르면 삼성전자는...
# 1277  전 세계적인 반도체 대란이 장기화하면서 스마트폰 가격 인상이 현실화하고 있다. \n...
# 1278  아이폰13 출시된 10월에만 \n이통3사 순증 가입 97만명 \n삼성 폴더블폰 Z시...
# 1279  애플은 전분기보다 5%P 감소 \n\n \n\n \n삼성전자가 올 3 4분기 갤럭시...
#
#                                                     URL 분석제외 여부
# 0     http://news.kmib.co.kr/article/view.asp?arcid=...     NaN
# 1     http://biz.heraldcorp.com/view.php?ud=20220307...     NaN
# 2            http://www.sedaily.com/NewsView/263BRBFNGS     NaN
# 3     http://www.seoul.co.kr/news/newsView.php?id=20...     NaN
# 4                  http://www.etnews.com/20220307000271     NaN
# ...                                                 ...     ...
# 1275  https://www.donga.com/news/article/all/2021120...     NaN
# 1276  http://news.mk.co.kr/newsRead.php?no=1119461&y...     NaN
# 1277                                                NaN     NaN
# 1278      http://www.fnnews.com/news/202112061750009245     NaN
# 1279      http://www.fnnews.com/news/202112061749443703     NaN
#
# [1280 rows x 19 columns]

# %%
df=pd.read_excel('./data/samsung_smartphone.xlsx')
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#          뉴스 식별자        일자    언론사             기고자  \
# 0  1.100201e+06  20220307   국민일보             양한주
# 1  2.100701e+06  20220307  헤럴드경제          박혜림 기자
# 2  2.100311e+06  20220307   서울경제          윤민혁 기자
# 3  1.100611e+06  20220307   서울신문             나상현
# 4  7.100501e+06  20220307   전자신문  전자신문인터넷 양민하 기자
#
#                                      제목     통합 분류1      통합 분류2 통합 분류3  \
# 0  삼성, 중저가 시장서 명예회복 노린다 A시리즈로 아이폰SE와 격돌  IT_과학>모바일   IT_과학>콘텐츠    NaN
# 1        “삼성, 정말 이래도 돼?” 싸다고 ‘이것’까지 없앤다  IT_과학>모바일   IT_과학>콘텐츠    NaN
# 2        삼성전자, '랩서스' 해킹 관해 "고객정보 유출 없어"   IT_과학>보안   IT_과학>모바일    NaN
# 3       삼성 “해킹 자료에 임직원 고객 개인 정보 포함 안됐다”   IT_과학>보안   IT_과학>모바일    NaN
# 4    "갤럭시A 붙자"...공개 임박 애플 '아이폰SE3' 스펙은?  IT_과학>모바일         NaN    NaN
#
#   사건/사고 분류1 사건/사고 분류2  사건/사고 분류3   인물      위치  \
# 0       NaN       NaN        NaN  NaN      중국
# 1       NaN       NaN        NaN  NaN     NaN
# 2       NaN       NaN        NaN  NaN      미국
# 3       NaN       NaN        NaN  NaN  미국,토렌트
# 4       NaN       NaN        NaN  NaN      양산
#
#                                        기관  \
# 0                          애플,옴디아,삼성전자,삼성
# 1                         애플,샘모바일,유럽,삼성전자
# 2               시큐리티팀,랩서스,퀄컴,삼성전자,MX,엔비디아
# 3            랩서스,시큐리티팀,삼성전자,삼성,MX사업부,엔비디아
# 4  궈밍치,애플,전자신문,JP모건,퀄컴,옴디아,삼성전자,GSM아레나,삼성
#
#                                                  키워드  \
# 0  삼성,중저,시장,명예회복,A시리즈,아이폰SE,격돌,삼성전자,공개,이달,갤럭시,시리즈...
# 1  삼성,충전기,삼성전자,구성품,중저가,스마트폰,충전기,불포함,충전기,어댑터,A13,시...
# 2  삼성전자,랩서스,해킹,고객,정보,유출,삼성전자,외국,해커,그룹,랩서스,APSUS,해...
# 3  자료,삼성,해킹,임직원,고객,포함,개인,정보,삼성전자,랩서스,외국,해커,그룹,APS...
# 4  아이폰SE3,갤럭시,공개,임박,애플,아이폰,SE,스펙,애플,이벤트,스페셜,아이폰SE...
#
#                                    특성추출(가중치순 상위 50개)  \
# 0  갤럭시,삼성전자,스마트폰,중저가,gos,업데이트,5g,옴디아,점유율,바이오닉,출하량...
# 1  갤럭시,충전기,스마트폰,삼성전자,중저가폰,중저가,샘모바일,구성품,a13,어댑,후속작...
# 2  삼성전자,랩서스,삼성,임직원,하드웨어,미국,트러스트존,사업부,보안시스템,그래픽카드,...
# 3  삼성전자,임직원,랩서스,미국,엔비디아,사업부,보안시스템,소스코드,토렌트,회로도,그래...
# 4  중저가,스마트폰,아이폰se3,갤럭시,삼성전자,출하량,사용자,64gb,상반기,옴디아,...
#
#                                                   본문  \
# 0  삼성전자가 이르면 이달 중 보급형 스마트폰인 갤럭시 A 시리즈를 선보인다. 2년 만...
# 1  [헤럴드경제=박혜림 기자] “싸다고 충전기까지 뺀다?” \n \n 삼성전자가 중저가...
# 2  삼성전자(005930)가 외국 해커 그룹 ‘랩서스(LAPSUS＄)’로부터 해킹 당했...
# 3  삼성전자가 최근 외국 해커그룹 랩서스(LAPSUS$)로부터 해킹 공격을 받은 것과 ...
# 4  애플이 오는 9일 스페셜 이벤트를 통해 '아이폰SE' 신제품을 선보일 전망이다. 홈...
#
#                                                  URL 분석제외 여부
# 0  http://news.kmib.co.kr/article/view.asp?arcid=...     NaN
# 1  http://biz.heraldcorp.com/view.php?ud=20220307...     NaN
# 2         http://www.sedaily.com/NewsView/263BRBFNGS     NaN
# 3  http://www.seoul.co.kr/news/newsView.php?id=20...     NaN
# 4               http://www.etnews.com/20220307000271     NaN

# %%
df.본문.head()
# Out:
# 0    삼성전자가 이르면 이달 중 보급형 스마트폰인 갤럭시 A 시리즈를 선보인다. 2년 만...
# 1    [헤럴드경제=박혜림 기자] “싸다고 충전기까지 뺀다?” \n \n 삼성전자가 중저가...
# 2    삼성전자(005930)가 외국 해커 그룹 ‘랩서스(LAPSUS＄)’로부터 해킹 당했...
# 3    삼성전자가 최근 외국 해커그룹 랩서스(LAPSUS$)로부터 해킹 공격을 받은 것과 ...
# 4    애플이 오는 9일 스페셜 이벤트를 통해 '아이폰SE' 신제품을 선보일 전망이다. 홈...
# Name: 본문, dtype: object

# %%
# !pip install eunjeon

# %%
posts = df.본문

# %%
from eunjeon import Mecab
tagger = Mecab()

# %%
stop_words = "중 년 은 이 것 등 더 를 좀 즉 인 옹 때 만 원 이때 개 일 기 시 럭 갤 성 삼 스 폰 트 드 기 이 리 폴 사 전 마 자 플 블 가 "

# %%
stop_words=stop_words.split(' ')
stop_words[0:10]
# Out:
# ['중', '년', '은', '이', '것', '등', '더', '를', '좀', '즉']

# %%
nouns = [ ]
for post in posts: 
    for noun in tagger.nouns(post):
        if noun not in stop_words:
            nouns.append(noun)

# %%
nouns[:20]
# Out:
# ['삼성전자',
#  '이달',
#  '보급',
#  '스마트폰',
#  '갤럭시',
#  '시리즈',
#  '보급',
#  '제품',
#  '출시',
#  '중저가',
#  '시장',
#  '공략',
#  '애플',
#  '견제',
#  '글로벌',
#  '시장',
#  '선두',
#  '취지',
#  '풀이',
#  '게임']

# %%
words = [ ]
for post in posts: 
    words.extend(tagger.pos(post)) # pos : part of speech(품사)

# %%
words[:10]
# Out:
# [('삼성전자', 'NNP'),
#  ('가', 'JKS'),
#  ('이르', 'VV'),
#  ('면', 'EC'),
#  ('이달', 'NNG'),
#  ('중', 'NNB'),
#  ('보급', 'NNG'),
#  ('형', 'XSN'),
#  ('스마트폰', 'NNP'),
#  ('인', 'VCP+ETM')]

# %%
verbs = [ ]
for word in words: 
    if word[1] == 'VV':
        verbs.append(word[0]+'다')

# %%
word[0] , word[1] # word[0]: 단어 , word[1]: 단어에 tagging 된 품사
# Out:
# ('.', 'SF')

# %%
verbs[:10]
# Out:
# ['이르다', '지키다', '있다', '넣다', '따르다', '받다', '오다', '치솟다', '앓다', '실다']

# %%
adjective = [ ] 
for word in words: 
    if word[1] == 'VA':
        adjective.append(word[0]+'다')

# %%
adjective[:10]
# Out:
# ['싸다', '높다', '없다', '많다', '좋다', '있다', '높다', '많다', '없다', '같다']

# %%
from collections import Counter 
   
counted_nouns = Counter(nouns) 
top_20 = counted_nouns.most_common(20)   
top_20
# Out:
# [('갤럭시', 1865),
#  ('삼성전자', 1795),
#  ('시리즈', 808),
#  ('스마트폰', 753),
#  ('삼성', 557),
#  ('공개', 478),
#  ('제품', 439),
#  ('시장', 391),
#  ('출시', 374),
#  ('더블', 350),
#  ('기자', 345),
#  ('세계', 270),
#  ('시간', 266),
#  ('모바일', 245),
#  ('중국', 243),
#  ('현지', 242),
#  ('미국', 241),
#  ('애플', 235),
#  ('기술', 216),
#  ('팩', 216)]
